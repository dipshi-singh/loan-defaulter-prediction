# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('dataa.csv')

# %%
df.sample(5)
# Out:
#                                  Unnamed: 0                 Disbdate  \
# 7554   6E881CBD-F4BA-4203-AC2F-E61C1BC067E4  2022-04-18 00:00:00.000
# 10512  2955D9C9-1664-458B-9724-F72A8E6A24CC  2022-09-14 00:00:00.000
# 18234  02895E8D-C25A-4A94-A0EC-8BE6A81DB5DF  2022-10-23 00:00:00.000
# 9334   3BB067CF-8908-4DCB-B37B-442713724FB1  2022-09-17 00:00:00.000
# 11422  588F9859-2694-4454-BFC5-1F504518BD06  2022-10-29 00:00:00.000
#
#                   loanpurpose  client_no_of_dependent ClientGender  \
# 7554       Tailoring Business                     5.0            M
# 10512  General Store Business                    11.0            M
# 18234    Cow Rearing Business                     NaN            M
# 9334       Tailoring Business                     5.0            M
# 11422      Tailoring Business                     NaN            M
#
#       marital_status  totalincome  loanexp  saving  totalexp  financeamt  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Disbdate', 'loanpurpose', 'client_no_of_dependent',
#        'ClientGender', 'marital_status', 'totalincome', 'loanexp', 'saving',
#        'totalexp', 'financeamt', 'period', 'emi', 'Interest', 'riskfund',
#        'irr', 'firstdateofinst', 'credit_status', 'equifax_score_retail',
#        'borrower_history', 'coborrower_history', 'new_to_credit',
#        'borrower_outstanding', 'dpd', 'lastpaiddate', 'last_month_paid',
#        'loan_end_date', 'total_emi_amt', 'total_emi_paid', 'outstanding_amt'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22725 entries, 0 to 22724
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              22725 non-null  object
#  1   Disbdate                22725 non-null  object
#  2   loanpurpose             22725 non-null  object
#  3   client_no_of_dependent  16752 non-null  float64
#  4   ClientGender            22725 non-null  object
#  5   marital_status          22725 non-null  object
#  6   totalincome             22725 non-null  int64
#  7   loanexp                 22725 non-null  int64
#  8   saving                  22725 non-null  int64
#  9   totalexp                22725 non-null  int64
#  10  financeamt              22725 non-null  int64
#  11  period                  22725 non-null  int64
#  12  emi                     22725 non-null  int64
#  13  Interest                22725 non-null  float64
# ...

# %%
df.drop('borrower_history',axis=1,inplace=True)

# %%
df.drop('coborrower_history',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22725 entries, 0 to 22724
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              22725 non-null  object
#  1   Disbdate                22725 non-null  object
#  2   loanpurpose             22725 non-null  object
#  3   client_no_of_dependent  16752 non-null  float64
#  4   ClientGender            22725 non-null  object
#  5   marital_status          22725 non-null  object
#  6   totalincome             22725 non-null  int64
#  7   loanexp                 22725 non-null  int64
#  8   saving                  22725 non-null  int64
#  9   totalexp                22725 non-null  int64
#  10  financeamt              22725 non-null  int64
#  11  period                  22725 non-null  int64
#  12  emi                     22725 non-null  int64
#  13  Interest                22725 non-null  float64
# ...

# %%
df['client_no_of_dependent'].unique()
# Out:
# array([ 2., 11.,  4.,  1.,  6.,  9.,  3.,  5.,  8.,  7., 10., nan,  0.])

# %%
print('% of null values in no of dependents ',(df['client_no_of_dependent'].isna().sum()/df.shape[0])*100)
# Out:
# % of null values in no of dependents  26.28382838283828

# %%
df[df['client_no_of_dependent'].isna()].head()
# Out:
#                                 Unnamed: 0                 Disbdate  \
# 1314  72D5E4A7-0F95-44A1-9DCB-B3F0D1110BC5  2021-03-11 00:00:00.000
# 1470  C2E3ADD8-B5B5-4D52-8811-6CF131DB8FFA  2021-03-12 00:00:00.000
# 1474  FB6D9ED8-002E-4814-8E66-6BD489DCE3ED  2021-03-22 00:00:00.000
# 1835  1D29F441-3671-4EF6-AE77-76C5E57582CA  2021-03-04 00:00:00.000
# 2000  B6EEA11E-3405-4077-BB9A-953278D4A224  2021-02-26 00:00:00.000
#
#                loanpurpose  client_no_of_dependent ClientGender  \
# 1314    Tailoring Business                     NaN            M
# 1470  Cow Rearing Business                     NaN            M
# 1474          Bag Business                     NaN            M
# 1835    Tailoring Business                     NaN            M
# 2000    Tailoring Business                     NaN            M
#
#      marital_status  totalincome  loanexp  saving  totalexp  financeamt  \
# 1314      Unmarried        57000     7677   44323     12677       40000
# ...

# %%
df[df['client_no_of_dependent'].isna()].groupby(['marital_status']).size()
# Out:
# marital_status
# Married         8
# Unmarried    5965
# dtype: int64

# %%
df.groupby(['marital_status'])['client_no_of_dependent'].apply(lambda x:x.mode().values)
# Out:
# marital_status
# Married      [5.0]
# Unmarried    [5.0]
# Name: client_no_of_dependent, dtype: object

# %%
df.groupby(['marital_status'])['client_no_of_dependent'].median()
# Out:
# marital_status
# Married      5.0
# Unmarried    4.0
# Name: client_no_of_dependent, dtype: float64

# %%
df.groupby(['marital_status','client_no_of_dependent']).size()
# Out:
# marital_status  client_no_of_dependent
# Married         0.0                         62
#                 1.0                        365
#                 2.0                        906
#                 3.0                       1916
#                 4.0                       2454
#                 5.0                       3790
#                 6.0                       2217
#                 7.0                        652
#                 8.0                        250
#                 9.0                        175
#                 10.0                       101
#                 11.0                       515
# Unmarried       0.0                         75
#                 1.0                        362
#                 2.0                        183
#                 3.0                        493
#                 4.0                        607
#                 5.0                        818
#                 6.0                        592
# ...

# %%
df['client_no_of_dependent'].fillna(df['client_no_of_dependent'].median(),inplace=True)

# %%
df['client_no_of_dependent'].unique()
# Out:
# array([ 2., 11.,  4.,  1.,  6.,  9.,  3.,  5.,  8.,  7., 10.,  0.])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22725 entries, 0 to 22724
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              22725 non-null  object
#  1   Disbdate                22725 non-null  object
#  2   loanpurpose             22725 non-null  object
#  3   client_no_of_dependent  22725 non-null  float64
#  4   ClientGender            22725 non-null  object
#  5   marital_status          22725 non-null  object
#  6   totalincome             22725 non-null  int64
#  7   loanexp                 22725 non-null  int64
#  8   saving                  22725 non-null  int64
#  9   totalexp                22725 non-null  int64
#  10  financeamt              22725 non-null  int64
#  11  period                  22725 non-null  int64
#  12  emi                     22725 non-null  int64
#  13  Interest                22725 non-null  float64
# ...

# %%
df[df['equifax_score_retail'].isna()]['new_to_credit'].sample(5)
# Out:
# 7962    1
# 6500    1
# 5415    1
# 1671    1
# 5702    1
# Name: new_to_credit, dtype: int64

# %%
df['equifax_score_retail'].isna().sum()
# Out:
# 4365

# %%
df[(df['equifax_score_retail'].isna())&(df['new_to_credit'].isin ([0,1]))]['new_to_credit'].sum()
# Out:
# 4214

# %%
df['new_to_credit'].unique()
# Out:
# array([0, 1])

# %%
df['new_to_credit'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 22725 entries, 0 to 22724
# Series name: new_to_credit
# Non-Null Count  Dtype
# --------------  -----
# 22725 non-null  int64
# dtypes: int64(1)
# memory usage: 177.7 KB

# %%
df[(df['equifax_score_retail'].isna())&(df['new_to_credit'].isna())].shape[0]
# Out:
# 0

# %%
df[(df['equifax_score_retail'].isna())&(df['new_to_credit']==0)].shape[0]
# Out:
# 151

# %%
df.drop(df[(df['equifax_score_retail'].isna()) & (df['new_to_credit'] == 0)].index, inplace=True)

# %%
df.shape
# Out:
# (22574, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22574 entries, 0 to 22724
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              22574 non-null  object
#  1   Disbdate                22574 non-null  object
#  2   loanpurpose             22574 non-null  object
#  3   client_no_of_dependent  22574 non-null  float64
#  4   ClientGender            22574 non-null  object
#  5   marital_status          22574 non-null  object
#  6   totalincome             22574 non-null  int64
#  7   loanexp                 22574 non-null  int64
#  8   saving                  22574 non-null  int64
#  9   totalexp                22574 non-null  int64
#  10  financeamt              22574 non-null  int64
#  11  period                  22574 non-null  int64
#  12  emi                     22574 non-null  int64
#  13  Interest                22574 non-null  float64
# ...

# %%
df[df['equifax_score_retail'].isna()]['new_to_credit'].unique()
# Out:
# array([1])

# %%
df['equifax_score_retail'].fillna(0,inplace=True)

# %%
df['equifax_score_retail'].isna().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22574 entries, 0 to 22724
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              22574 non-null  object
#  1   Disbdate                22574 non-null  object
#  2   loanpurpose             22574 non-null  object
#  3   client_no_of_dependent  22574 non-null  float64
#  4   ClientGender            22574 non-null  object
#  5   marital_status          22574 non-null  object
#  6   totalincome             22574 non-null  int64
#  7   loanexp                 22574 non-null  int64
#  8   saving                  22574 non-null  int64
#  9   totalexp                22574 non-null  int64
#  10  financeamt              22574 non-null  int64
#  11  period                  22574 non-null  int64
#  12  emi                     22574 non-null  int64
#  13  Interest                22574 non-null  float64
# ...

# %%
df[df['total_emi_paid'].isna()][['last_month_paid','lastpaiddate','total_emi_paid','outstanding_amt']]
# Out:
#       last_month_paid lastpaiddate  total_emi_paid  outstanding_amt
# 1378              NaN          NaN             NaN              NaN
# 1403              NaN          NaN             NaN              NaN
# 1470              NaN          NaN             NaN              NaN
# 1544              NaN          NaN             NaN              NaN
# 1573              NaN          NaN             NaN              NaN
# 1682              NaN          NaN             NaN              NaN
# 1701              NaN          NaN             NaN              NaN
# 1710              NaN          NaN             NaN              NaN
# 1878              NaN          NaN             NaN              NaN
# 2006              NaN          NaN             NaN              NaN
# 2016              NaN          NaN             NaN              NaN
# 2018              NaN          NaN             NaN              NaN
# 2162              NaN          NaN             NaN              NaN
# ...

# %%
df['last_month_paid'].isna().sum()
# Out:
# 53

# %%
df.shape
# Out:
# (22574, 28)

# %%
df.drop(df[df['last_month_paid'].isna()].index,inplace=True)

# %%
df.shape
# Out:
# (22521, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22521 entries, 0 to 22724
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              22521 non-null  object
#  1   Disbdate                22521 non-null  object
#  2   loanpurpose             22521 non-null  object
#  3   client_no_of_dependent  22521 non-null  float64
#  4   ClientGender            22521 non-null  object
#  5   marital_status          22521 non-null  object
#  6   totalincome             22521 non-null  int64
#  7   loanexp                 22521 non-null  int64
#  8   saving                  22521 non-null  int64
#  9   totalexp                22521 non-null  int64
#  10  financeamt              22521 non-null  int64
#  11  period                  22521 non-null  int64
#  12  emi                     22521 non-null  int64
#  13  Interest                22521 non-null  float64
# ...

# %%
df[~df['borrower_outstanding'].isna()][['lastpaiddate','last_month_paid','outstanding_amt','borrower_outstanding']].head(50)
# Out:
#                lastpaiddate last_month_paid  outstanding_amt  \
# 0   2021-11-10 12:44:00.000      2021-11-10          54400.0
# 1   2022-12-27 16:10:00.000      2022-12-27          34000.0
# 2   2022-08-19 10:13:00.000      2022-08-19          34100.0
# 3   2022-10-17 15:17:00.000      2022-10-17          12600.0
# 4   2022-08-20 13:46:00.000      2022-08-20            470.0
# 5   2022-11-30 21:01:00.000      2022-11-30              0.0
# 6   2023-03-02 20:56:00.000      2023-03-02           3750.0
# 7   2023-01-29 11:08:00.000      2023-01-29          -3000.0
# 8   2022-12-27 13:09:00.000      2022-12-27          10600.0
# 9   2022-12-31 10:30:00.000      2022-12-31              0.0
# 10  2022-09-24 15:08:00.000      2022-09-24          13600.0
# 11  2022-04-24 10:40:00.000      2022-04-24          31500.0
# 12  2022-01-18 15:57:00.000      2022-01-18             70.0
# 13  2021-04-05 03:26:00.000      2021-04-05          71400.0
# ...

# %%
df.drop('borrower_outstanding',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22521 entries, 0 to 22724
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              22521 non-null  object
#  1   Disbdate                22521 non-null  object
#  2   loanpurpose             22521 non-null  object
#  3   client_no_of_dependent  22521 non-null  float64
#  4   ClientGender            22521 non-null  object
#  5   marital_status          22521 non-null  object
#  6   totalincome             22521 non-null  int64
#  7   loanexp                 22521 non-null  int64
#  8   saving                  22521 non-null  int64
#  9   totalexp                22521 non-null  int64
#  10  financeamt              22521 non-null  int64
#  11  period                  22521 non-null  int64
#  12  emi                     22521 non-null  int64
#  13  Interest                22521 non-null  float64
# ...

# %%
#changing data types

# %%
df['Disbdate']=pd.to_datetime(df['Disbdate'])

# %%
df['firstdateofinst']=pd.to_datetime(df['firstdateofinst'])
df['lastpaiddate']=pd.to_datetime(df['lastpaiddate'])
df['loan_end_date']=pd.to_datetime(df['loan_end_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22521 entries, 0 to 22724
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              22521 non-null  object
#  1   Disbdate                22521 non-null  datetime64[ns]
#  2   loanpurpose             22521 non-null  object
#  3   client_no_of_dependent  22521 non-null  float64
#  4   ClientGender            22521 non-null  object
#  5   marital_status          22521 non-null  object
#  6   totalincome             22521 non-null  int64
#  7   loanexp                 22521 non-null  int64
#  8   saving                  22521 non-null  int64
#  9   totalexp                22521 non-null  int64
#  10  financeamt              22521 non-null  int64
#  11  period                  22521 non-null  int64
#  12  emi                     22521 non-null  int64
#  13  Interest                22521 non-null  float64
# ...

# %%
pd.set_option('display.max_columns', None)
df.head(10)
# Out:
#                              Unnamed: 0   Disbdate  \
# 0  996324FB-7E09-44CD-BBC9-A74C2F3A20B6 2021-03-19
# 1  954C84F4-1BDB-4018-8B1A-8259735BF7E2 2021-08-02
# 2  4D962480-402A-4055-9680-DEC8AC0FDF9C 2022-08-16
# 3  2CA9EFAD-53E8-4399-8B3E-6CF73C152B6A 2022-01-29
# 4  ABD0D374-D94B-4F66-93C2-190C92E9E2A4 2021-10-27
# 5  0CECF1B0-7560-4D94-A713-DFE6A0B66FE7 2021-10-12
# 6  D0796A35-2AF4-495C-B639-770B44E77537 2021-12-02
# 7  3D095991-EB42-4B38-8199-D376AF39BBDF 2021-01-04
# 8  79BE2382-6FF8-4974-B285-EFD16B2CB080 2021-04-06
# 9  E69A4D35-37A3-4DAC-B8DC-A96BA7C5FB1C 2021-01-06
#
#                     loanpurpose  client_no_of_dependent ClientGender  \
# 0      Buffalo Rearing Business                     2.0            M
# 1      Buffalo Rearing Business                    11.0            M
# 2            Tailoring Business                     4.0            M
# 3        General Store Business                     1.0            M
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Disbdate', 'loanpurpose', 'client_no_of_dependent',
#        'ClientGender', 'marital_status', 'totalincome', 'loanexp', 'saving',
#        'totalexp', 'financeamt', 'period', 'emi', 'Interest', 'riskfund',
#        'irr', 'firstdateofinst', 'credit_status', 'equifax_score_retail',
#        'new_to_credit', 'dpd', 'lastpaiddate', 'last_month_paid',
#        'loan_end_date', 'total_emi_amt', 'total_emi_paid', 'outstanding_amt'],
#       dtype='object')

# %%
df['loanpurpose'].unique()
# Out:
# array(['Buffalo Rearing Business', 'Tailoring Business',
#        'General Store Business', 'Cow Rearing Business',
#        'Garage Workshop', 'Salon (Barber Shop) Business',
#        'Milk Selling Business', 'Electrical Business', 'Cloth Business',
#        'Goat Rearing Business', 'Other', 'Furniture Business',
#        'Cosmetics Business', 'Sweet Shop Business', 'Photo Studio Shop',
#        'Paper Plates (Dona) Business', 'Food Eatery (Dhaba)',
#        'Tea Shop Business', 'Meat Business', 'Dairy and Livestock',
#        'Mobile Shop Business', 'Services', 'Fruit & Vegetable Business',
#        'Stationery Shop', 'Medical Store', 'Agriculture',
#        'Band Baja Business', 'Footwear Business',
#        'Printing Press Business', 'Atta Chakki (Flour grinding) Business',
#        'Shuttering Business', 'Stone Work Business', 'Scrap Business',
#        'Small Comercial Vehicle Business', 'Transport Business',
# ...

# %%
category_mapping = {
    'Animal Rearing': ['Buffalo Rearing Business', 'Cow Rearing Business', 'Goat Rearing Business', 'Dairy and Livestock', 'Pig Rearing Business', 'Poultry  Business', 'Farming (Animal Feed) Business ','Milk Selling Business'],
    'Textile': ['Handloom Business','Tent House Business','Tailoring Business', 'Cloth Business'],
    'Automobile': ['Small Comercial Vehicle Business','Two Wheeler Resale Business','Motor Vehicle Repair Business','Cycle Repair Business','Small Comercial Vehicle Business', 'Transport Business', 'Garage Workshop'],
    'Grooming and Style': ['Beauty Parlour Business','Optical Shop','Footwear Business','Salon (Barber Shop) Business','Cosmetics Business'],
    'Furniture': ['Furniture Business'],
    'Food': [ 'Fish Selling Business','Rice Selling Business','Bakery/Caterering Shop','Eggs Selling Business','Atta Chakki (Flour grinding) Business','Fruit & Vegetable Business','Meat Business', 'Dairy and Livestock','Tea Shop Business','Food Eatery (Dhaba)', 'Bakery/Catering Shop', 'Food Business', 'Sweet Shop Business'],
    'Electronics': ['Mobile Shop Business',  'DJ Sound & Light Business', 'Electrical Business'],
    'Medical': ['Medical Store','Clinic shop'],
    'Agriculture': ['Agriculture Business','Agriculture'],
    'Entertainment': ['Photo Studio Shop', 'Tent House Business','Music and CD Shop Business', 'Cyber Cafe', 'Band Baja Business'],
    'Hardware': ['Spare Parts Shop','Metal Works Business','Hardware Shop', 'Scrap Business','Shuttering Business'],
    'Decoration': ['Flowers Business'],
    'Accessories': ['Bangles Business','Stationery Shop','Jewellery Shop','Toys/Gift Shop Business',  'Bag Business'],
    'Construction': ['Furnace Business', 'Water Plant/ Supplies Services Business','Construction Material Trading Business','Gas Supply Business','Iron Press Business','Stone Work Business'],
    'Others': ['Trading', 'Retail','Handicrafts Business','Worship Material Shop', 'Handicrafts Business','Paper Plates (Dona) Business','Other', 'Retail','General Store Business'],
    'Services':['Hand Press Machine Business','Services','Dry Cleanting/ Laundry Business','Trading Business',  'Welding Business', 'Printing Press Business','Vehicle Washing Business'],
'Manufacturing':['Food/Beverage Manufacturing Business','Worship Material Shop','Agarbatti  Manufacturing Business','Wood Work Business','Box Making  Business','Crockery Business']
}

# %%
df['business_category'] = df['loanpurpose'].apply(lambda x: next((category for category, purposes in category_mapping.items() if x in purposes), 'Others'))

# %%
df['business_category'].value_counts()
# Out:
# Animal Rearing        9656
# Textile               6246
# Others                2641
# Food                  1145
# Grooming and Style     675
# Electronics            439
# Hardware               366
# Services               344
# Automobile             220
# Furniture              186
# Medical                164
# Accessories            141
# Entertainment          127
# Manufacturing           58
# Agriculture             56
# Construction            51
# Decoration               6
# Name: business_category, dtype: int64

# %%
df['business_category']=df['business_category'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22521 entries, 0 to 22724
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              22521 non-null  object
#  1   Disbdate                22521 non-null  datetime64[ns]
#  2   loanpurpose             22521 non-null  object
#  3   client_no_of_dependent  22521 non-null  float64
#  4   ClientGender            22521 non-null  object
#  5   marital_status          22521 non-null  object
#  6   totalincome             22521 non-null  int64
#  7   loanexp                 22521 non-null  int64
#  8   saving                  22521 non-null  int64
#  9   totalexp                22521 non-null  int64
#  10  financeamt              22521 non-null  int64
#  11  period                  22521 non-null  int64
#  12  emi                     22521 non-null  int64
#  13  Interest                22521 non-null  float64
# ...

# %%
df['id']=range(10001,10001+len(df))

# %%
df = df[['id'] + [col for col in df if col != 'id']]

# %%
df.head()
# Out:
#       id                            Unnamed: 0   Disbdate  \
# 0  10001  996324FB-7E09-44CD-BBC9-A74C2F3A20B6 2021-03-19
# 1  10002  954C84F4-1BDB-4018-8B1A-8259735BF7E2 2021-08-02
# 2  10003  4D962480-402A-4055-9680-DEC8AC0FDF9C 2022-08-16
# 3  10004  2CA9EFAD-53E8-4399-8B3E-6CF73C152B6A 2022-01-29
# 4  10005  ABD0D374-D94B-4F66-93C2-190C92E9E2A4 2021-10-27
#
#                 loanpurpose  client_no_of_dependent ClientGender  \
# 0  Buffalo Rearing Business                     2.0            M
# 1  Buffalo Rearing Business                    11.0            M
# 2        Tailoring Business                     4.0            M
# 3    General Store Business                     1.0            M
# 4      Cow Rearing Business                     6.0            M
#
#   marital_status  totalincome  loanexp  saving  totalexp  financeamt  period  \
# 0        Married        24000     3625       0      7625       60000      24
# ...

# %%
df.drop(columns=['Unnamed: 0','credit_status'],axis=1,inplace=True)
# Out:
# <ipython-input-193-ce6c747aa029>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Unnamed: 0','credit_status'],axis=1,inplace=True)

# %%
df.head()
# Out:
#       id   Disbdate               loanpurpose  client_no_of_dependent  \
# 0  10001 2021-03-19  Buffalo Rearing Business                     2.0
# 1  10002 2021-08-02  Buffalo Rearing Business                    11.0
# 2  10003 2022-08-16        Tailoring Business                     4.0
# 3  10004 2022-01-29    General Store Business                     1.0
# 4  10005 2021-10-27      Cow Rearing Business                     6.0
#
#   ClientGender marital_status  totalincome  loanexp  saving  totalexp  \
# 0            M        Married        24000     3625       0      7625
# 1            M        Married        22000     5150       0      8750
# 2            M        Married        50000     8599   36401     13599
# 3            M        Married        59000    11666   45234     13766
# 4            M        Married        24000     4860       0     14860
#
#    financeamt  period   emi  Interest  riskfund       irr firstdateofinst  \
# ...

# %%
#creating column to flag defaulter
df['defaulter_flag'] = df['dpd'].apply(lambda x: 1 if x>90 else 0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22521 entries, 0 to 22724
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      22521 non-null  int64
#  1   Disbdate                22521 non-null  datetime64[ns]
#  2   loanpurpose             22521 non-null  object
#  3   client_no_of_dependent  22521 non-null  float64
#  4   ClientGender            22521 non-null  object
#  5   marital_status          22521 non-null  object
#  6   totalincome             22521 non-null  int64
#  7   loanexp                 22521 non-null  int64
#  8   saving                  22521 non-null  int64
#  9   totalexp                22521 non-null  int64
#  10  financeamt              22521 non-null  int64
#  11  period                  22521 non-null  int64
#  12  emi                     22521 non-null  int64
#  13  Interest                22521 non-null  float64
# ...

# %%
df['ClientGender']=df['ClientGender'].astype('category')
df['marital_status']=df['marital_status'].astype('category')
df['last_month_paid']=pd.to_datetime(df['last_month_paid'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22521 entries, 0 to 22724
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      22521 non-null  int64
#  1   Disbdate                22521 non-null  datetime64[ns]
#  2   loanpurpose             22521 non-null  object
#  3   client_no_of_dependent  22521 non-null  float64
#  4   ClientGender            22521 non-null  category
#  5   marital_status          22521 non-null  category
#  6   totalincome             22521 non-null  int64
#  7   loanexp                 22521 non-null  int64
#  8   saving                  22521 non-null  int64
#  9   totalexp                22521 non-null  int64
#  10  financeamt              22521 non-null  int64
#  11  period                  22521 non-null  int64
#  12  emi                     22521 non-null  int64
#  13  Interest                22521 non-null  float64
# ...

# %%
df.to_csv('Cleaned_data.csv',index=False)

# %%
df1=pd.read_csv('Cleaned_data.csv')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22521 entries, 0 to 22520
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      22521 non-null  int64
#  1   Disbdate                22521 non-null  object
#  2   loanpurpose             22521 non-null  object
#  3   client_no_of_dependent  22521 non-null  float64
#  4   ClientGender            22521 non-null  object
#  5   marital_status          22521 non-null  object
#  6   totalincome             22521 non-null  int64
#  7   loanexp                 22521 non-null  int64
#  8   saving                  22521 non-null  int64
#  9   totalexp                22521 non-null  int64
#  10  financeamt              22521 non-null  int64
#  11  period                  22521 non-null  int64
#  12  emi                     22521 non-null  int64
#  13  Interest                22521 non-null  float64
# ...
